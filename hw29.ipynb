# %%
import pandas as pd
from IPython.display import display
sports = pd.read_csv(r'sport_athletes.csv')
#1

display(sports)
display(sports.groupby("Sport Type")[['Weight(kg)', 'Height(cm)', 'Wins']].max().rename(columns={'Weight(kg)':"max_weight", 'Height(cm)':"max_height", 'Wins':"max_wins"}))
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %%
#2
display(sports.groupby("Sport Type")[['Weight(kg)', 'Height(cm)', 'Wins']].min().sort_values(by='Weight(kg)', ascending = True))
# Out:
#                  Weight(kg)  Height(cm)  Wins
# Sport Type
# Basketball               96         198     1
# Tennis                   70         175     2
# Cycling                  68         175     3
# Swimming                 58         180     3
# Soccer                   57         163     2
# Track and Field          57         165     3
# Gymnastics               45         142     3

# %%
#3
display(sports[["Sport Type", "Athlete Name", 'Height(cm)']].sort_values(by="Height(cm)", ascending = False).groupby("Sport Type").head(2))
# Out:
#          Sport Type       Athlete Name  Height(cm)
# 4        Basketball   Shaquille O'Neal         216
# 3        Basketball       Kevin Durant         208
# 15         Swimming           Sun Yang         200
# 14         Swimming         Ian Thorpe         196
# 20  Track and Field         Usain Bolt         195
# 21  Track and Field         Carl Lewis         188
# 19           Tennis     Novak Djokovic         188
# 7            Soccer  Cristiano Ronaldo         187
# 28          Cycling      Primoz Roglic         186
# 16           Tennis      Roger Federer         185
# 9            Soccer    Zinedine Zidane         185
# 27          Cycling      Tadej Pogacar         184
# 33       Gymnastics        Aly Raisman         160
# 34       Gymnastics      Shawn Johnson         157

# %%
#4
#a
display(sports.groupby(["Sport Type", "Country"]).max())

#b
display(sports.groupby(["Sport Type", "Country"]).max().head(1))

#c
display(sports.groupby(["Sport Type", "Country"]).max().xs('Soccer'))

#d
display(sports.groupby(["Sport Type", "Country"]).max().loc[['Soccer', 'Tennis']])

#e
display(sports.groupby(["Sport Type", "Country"]).max().swaplevel())

#f
display(sports.groupby(["Sport Type", "Country"]).agg({"Wins":['max', 'mean', 'min', 'std'], "Height(cm)":['max', 'mean', 'min', 'std']}))
# Out:
#                                      Athlete Name  Height(cm)  Weight(kg)  \
# Sport Type      Country
# Basketball      USA              Shaquille O'Neal         216         147
# Cycling         Belgium               Eddy Merckx         181          72
#                 Netherlands  Anna van der Breggen         175          68
#                 Slovenia            Tadej Pogacar         186          69
#                 UK                 Geraint Thomas         183          71
# Gymnastics      Romania            Nadia Comaneci         155          50
#                 USA                  Simone Biles         160          52
# Soccer          Argentina            Lionel Messi         170          69
#                 Brazil                       Pelé         174          72
#                 France            Zinedine Zidane         185          80
#                 Portugal        Cristiano Ronaldo         187          83
# ...

# %%
#5
new_rows = pd.DataFrame({ 'Country': ['Canada', 'USA'], 'Sport Type': ['Hockey', 'Skiing'],
'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'], 'Height(cm)': [183, 172],
'Weight(kg)': [84, 68], 'Wins': [3, 4], 'Olympic Date': ['01/02/2002', '12/02/2010'] })
new_sports = pd.concat([sports, new_rows], axis = 0).reset_index()
# Out:
#     index      Country       Sport Type          Athlete Name  Height(cm)  \
# 0       0          USA       Basketball        Michael Jordan         198
# 1       1          USA       Basketball          LeBron James         206
# 2       2          USA       Basketball           Kobe Bryant         198
# 3       3          USA       Basketball          Kevin Durant         208
# 4       4          USA       Basketball      Shaquille O'Neal         216
# 5       5       Brazil           Soccer                  Pelé         174
# 6       6       Brazil           Soccer                 Marta         163
# 7       7     Portugal           Soccer     Cristiano Ronaldo         187
# 8       8    Argentina           Soccer          Lionel Messi         170
# 9       9       France           Soccer       Zinedine Zidane         185
# 10     10          USA           Soccer         Megan Rapinoe         168
# 11     11          USA         Swimming        Michael Phelps         193
# ...

# %%
#6
#new_sports["Olympic Date"] = pd.to_datetime(new_sports["Olympic Date"], format='%d/%m/%Y', errors='coerce')
#new_sports.set_index("Olympic Date", inplace=True)
display(new_sports)
display(new_sports["Wins"])
#אני באמת לא מבין איך לעשות את זה, שוב פעם קפיצה אדירה בחומר יחסית לשיעורים הקודמים
#יותר מזה, איך שהוא התוכנה זוכרת את הקוד שעשיתי בהערה והשאירה את הדייט כאינדקס אין לי מושג איך
#ובגלל זה הריסמפל לא עובד, כל פעם שאני עושה ריפרש הוא שוכח ואז אחרי הרצה אחת הוא זוכר ואני חייב לרענן כל פעם
# Out:
#               index      Country       Sport Type          Athlete Name  \
# Olympic Date
# 1992-08-08        0          USA       Basketball        Michael Jordan
# 2008-08-15        1          USA       Basketball          LeBron James
# 2012-08-24        2          USA       Basketball           Kobe Bryant
# 2016-08-10        3          USA       Basketball          Kevin Durant
# 2000-08-22        4          USA       Basketball      Shaquille O'Neal
# 1970-08-18        5       Brazil           Soccer                  Pelé
# 2004-08-01        6       Brazil           Soccer                 Marta
# 2008-08-25        7     Portugal           Soccer     Cristiano Ronaldo
# 2016-08-11        8    Argentina           Soccer          Lionel Messi
# 1998-08-17        9       France           Soccer       Zinedine Zidane
# 2020-08-05       10          USA           Soccer         Megan Rapinoe
# 2004-08-16       11          USA         Swimming        Michael Phelps
# ...

# %%
#7
smoke = pd.read_csv(r"athletes_smoking.csv")
display(pd.merge(smoke, new_sports, how="left"))
display(pd.merge(new_sports, smoke, outer="full"))
# Out:
#          Athlete Name Smoking  index    Country       Sport Type  Height(cm)  \
# 0      Michael Jordan      No      0        USA       Basketball         198
# 1        LeBron James      No      1        USA       Basketball         206
# 2         Kobe Bryant     Yes      2        USA       Basketball         198
# 3          Usain Bolt      No     20    Jamaica  Track and Field         195
# 4        Simone Biles      No     31        USA       Gymnastics         142
# 5       Wayne Gretzky     Yes      0     Canada           Hockey         183
# 6        Lindsey Vonn      No      1        USA           Skiing         172
# 7        Rafael Nadal      No     18      Spain           Tennis         185
# 8        Lionel Messi     Yes      8  Argentina           Soccer         170
# 9   Cristiano Ronaldo      No      7   Portugal           Soccer         187
# 10      Megan Rapinoe      No     10        USA           Soccer         168
# ...
